# %%
from model.GraphComplete import GraphComplete

# %%
graph = GraphComplete.of("Passion_Xtreme_III.mat", "NameTypes.xlsx")
# Out:
# Nodes: 154
# Links: 348
# Discarded nodes: 39
# Discarded links: 0
# Remaining nodes: 154
# Remaining links: 174
# Vertexs: 154
# Edges: 174
# LinksObj: 174
# NodesObj: 154

# %%
graph.vertexs
# Out:
# [Vertex(pos=(-0.3427555207831287, 0.7832944463895565), degree=2, name='02-00001_AN_1', type='HL5'),
#  Vertex(pos=(-0.010892967629246094, -0.11819118063981306), degree=3, name='02-00002_AN_1', type='HL5'),
#  Vertex(pos=(0.4500867656274771, -0.30179398425575676), degree=2, name='02-00006_AN_1', type='HL5'),
#  Vertex(pos=(-0.27575462591972116, -0.5240155592202371), degree=2, name='02-00007_AN_1', type='HL5'),
#  Vertex(pos=(0.3147377628688597, -0.16991724098223243), degree=2, name='02-00008_AN_1', type='HL5'),
#  Vertex(pos=(-0.10655742764174382, -0.3564235787156446), degree=2, name='02-00010_AN_1', type='HL5'),
#  Vertex(pos=(0.32579079538396793, 0.1593980474535695), degree=4, name='02-00012_AN_1', type='HL5'),
#  Vertex(pos=(0.04839742483810043, -0.5453295821636381), degree=2, name='02-00013_AN_1', type='HL5'),
#  Vertex(pos=(0.4872311192994016, 0.1175738824904022), degree=3, name='02-00014_AN_1', type='HL5'),
# ...

# %%
graph.edges
# Out:
# [Edge(a=(-0.3427555207831287, 0.7832944463895565), b=(-0.36418672754377457, 0.7143125890331139), distance=1.2, label='1.20km'),
#  Edge(a=(-0.3427555207831287, 0.7832944463895565), b=(-0.28667653041088104, 0.7790111232168507), distance=0.8809550931493786, label='0.88km'),
#  Edge(a=(-0.010892967629246094, -0.11819118063981306), b=(0.1306951779248449, -0.16373919852444913), distance=3.761828731593107, label='3.76km'),
#  Edge(a=(-0.010892967629246094, -0.11819118063981306), b=(0.16560368395697464, -0.08602471077715), distance=1.4439893185041621, label='1.44km'),
#  Edge(a=(-0.010892967629246094, -0.11819118063981306), b=(-0.28768452807975986, -0.14389277317286997), distance=3.2, label='3.20km'),
#  Edge(a=(0.4500867656274771, -0.30179398425575676), b=(0.3618424517668971, -0.18894483482724866), distance=5.5, label='5.50km'),
#  Edge(a=(0.4500867656274771, -0.30179398425575676), b=(0.356425008391913, -0.25640483921272034), distance=4.0, label='4.00km'),
# ...

# %%
graph.nodesObj
# Out:
# [NodeCrossRef(name='02-00001_AN_1', pos=(-0.3427555207831287, 0.7832944463895565), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]),
#  NodeCrossRef(name='02-00002_AN_1', pos=(-0.010892967629246094, -0.11819118063981306), node_degree=3, type='HL5', assoc_links=[], assoc_nodes=[]),
#  NodeCrossRef(name='02-00006_AN_1', pos=(0.4500867656274771, -0.30179398425575676), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]),
#  NodeCrossRef(name='02-00007_AN_1', pos=(-0.27575462591972116, -0.5240155592202371), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]),
#  NodeCrossRef(name='02-00008_AN_1', pos=(0.3147377628688597, -0.16991724098223243), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]),
#  NodeCrossRef(name='02-00010_AN_1', pos=(-0.10655742764174382, -0.3564235787156446), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]),
# ...

# %%
graph.linksObj
# Out:
# [LinkCrossRef(a=NodeCrossRef(name='02-00001_AN_1', pos=(-0.3427555207831287, 0.7832944463895565), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]), b=NodeCrossRef(name='02-03095_AN_1', pos=(-0.36418672754377457, 0.7143125890331139), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]), distance_km=1.2, label='1.20km'),
#  LinkCrossRef(a=NodeCrossRef(name='02-00001_AN_1', pos=(-0.3427555207831287, 0.7832944463895565), node_degree=2, type='HL5', assoc_links=[], assoc_nodes=[]), b=NodeCrossRef(name='02-03021_AN_1', pos=(-0.28667653041088104, 0.7790111232168507), node_degree=2, type='HL4', assoc_links=[], assoc_nodes=[]), distance_km=0.8809550931493786, label='0.88km'),
# ...

# %%
from model.Plotteable import Edge, Vertex

# %%
x, y = Vertex.obtain_x_y_vectors(graph.vertexs)
names = Vertex.obtain_name_vector(graph.vertexs)
degrees = Vertex.obtain_degree_vector(graph.vertexs)
types = Vertex.obtain_type_vector(graph.vertexs)

# %%
print(len(x))
x
# Out:
# 154
# [-0.3427555207831287,
#  -0.010892967629246094,
#  0.4500867656274771,
#  -0.27575462591972116,
#  0.3147377628688597,
#  -0.10655742764174382,
#  0.32579079538396793,
#  0.04839742483810043,
#  0.4872311192994016,
#  0.40040070729916527,
#  0.6213018017167351,
#  -0.40636720475963445,
#  0.18174933935927307,
#  -0.5349775078838446,
#  0.7556236563700566,
#  0.08109386908130126,
#  -0.756721771527661,
#  0.019525228244987848,
#  0.09538413371125762,
#  0.18364991456507787,
#  0.1306951779248449,
#  -0.7488357636539448,
#  -0.0677087960528958,
#  -0.7090020042960723,
#  -0.3635944096434775,
#  0.1984805526666983,
#  0.3338773940721191,
#  -0.15678817747131754,
#  -0.27704701813764493,
#  -0.3794986390077221,
#  0.4445750496126489,
#  -0.3298199934182263,
#  -0.5810810870732872,
#  -0.3792013466352908,
#  -0.5966333901526729,
#  0.8164958001700842,
#  -0.6361067196756108,
#  -0.05267363642072141,
#  0.30692289755945407,
#  0.2848570599541313,
#  0.3618424517668971,
# ...

# %%
print(len(y))
y
# Out:
# 154
# [0.7832944463895565,
#  -0.11819118063981306,
#  -0.30179398425575676,
#  -0.5240155592202371,
#  -0.16991724098223243,
#  -0.3564235787156446,
#  0.1593980474535695,
#  -0.5453295821636381,
#  0.1175738824904022,
#  -0.06747386353292796,
#  0.14029011073384065,
#  -0.7078843301291601,
#  -0.22864588669247704,
#  -0.4939769777032251,
#  -0.21707872399015113,
#  -0.3727790271215175,
#  0.384307115313631,
#  0.11947913622064289,
#  -0.8637959399872449,
#  -0.29312659268500585,
#  -0.16373919852444913,
#  -0.23662407521614112,
#  0.23312887271011995,
#  -0.39673312012147866,
#  -0.6466633681499427,
#  0.21719750055202597,
#  0.47002504361151637,
#  -0.08758597917566999,
#  -0.16293833484877396,
#  -0.15965524747392507,
#  0.19514148345295304,
#  -0.24764469124092,
#  -0.2030788307993813,
#  0.548122806376734,
#  0.6619625854443053,
#  0.16367745494433453,
#  0.48641526053486167,
#  -0.33408415654625967,
#  -0.35395474812553873,
#  -0.4335320743989229,
#  -0.18894483482724866,
# ...

# %%
print(len(names))
names
# Out:
# 154
# ['02-00001_AN_1',
#  '02-00002_AN_1',
#  '02-00006_AN_1',
#  '02-00007_AN_1',
#  '02-00008_AN_1',
#  '02-00010_AN_1',
#  '02-00012_AN_1',
#  '02-00013_AN_1',
#  '02-00014_AN_1',
#  '02-00015_AN_1',
#  '02-00017_AN_1',
#  '02-00019_AN_1',
#  '02-00021_AN_1',
#  '02-00028_AN_1',
#  '02-00033_AN_1',
#  '02-00034_AN_1',
#  '02-00036_AN_1',
#  '02-00039_AN_1',
#  '02-00040_AN_1',
#  '02-00046_AN_1',
#  '02-00051_AN_1',
#  '02-00052_AN_1',
#  '02-00054_AN_1',
#  '02-00057_AN_1',
#  '02-00058_AN_1',
#  '02-00059_AN_1',
#  '02-00068_AN_1',
#  '02-00200_AN_1',
#  '02-00201_AN_1',
#  '02-00202_AN_1',
#  '02-00205_AN_1',
#  '02-00206_AN_1',
#  '02-00207_AN_1',
#  '02-00212_AN_1',
#  '02-00502_AN_1',
#  '02-00904_AN_1',
#  '02-00906_AN_1',
#  '02-02202_AN_1',
#  '02-02205_AN_1',
#  '02-02206_AN_1',
#  '02-02210_AN_1',
#  '02-02212_AN_1',
#  '02-02218_AN_1',
#  '02-02223_AN_1',
#  '02-02224_AN_1',
#  '02-02225_AN_1',
#  '02-02235_AN_1',
#  '02-02238_AN_1',
#  '02-02242_AN_1',
# ...

# %%
print(len(degrees))
degrees
# Out:
# 154
# [2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  4,
#  2,
#  3,
#  2,
#  2,
#  1,
#  1,
#  3,
#  2,
#  2,
#  2,
#  6,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  3,
#  2,
#  3,
#  4,
#  5,
#  2,
#  2,
#  2,
#  10,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  7,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  3,
#  2,
#  4,
#  2,
#  1,
#  4,
#  2,
#  2,
#  2,
#  7,
#  5,
#  5,
#  1,
#  2,
#  2,
#  3,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2]

# %%
print(len(types))
types
# Out:
# 154
# ['HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
#  'HL5',
# ...

# %% [markdown]
# # Plots

# %%
from model.GraphComplete import GraphCompletePlots

# %%
GraphCompletePlots.plot_without_map(graph)

# %%
graph.plot_graph()
# Out:
# /home/elig/.cache/pypoetry/virtualenvs/pof-simulation-python-Sj3CBpnm-py3.11/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:457: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(
# ✅ Figura guardada como: grafo_distancias.png

# %%
graph.plot_graph_with_map()
# Out:
# ✅ Mapa guardado como: grafo_distancias.png
